# %% [markdown]
# O chat GPT é muito melhhor que o Gemini!

# %%
print (29)
# Out:
# 29

# %% [markdown]
# # Meu primeiro notebook Jupyter
#
# Este é um exemplo simples usando Python no Jupyter Notebook.

# %%
print("Olá, Jupyter!")
print(10 + 5)
# Out:
# Olá, Jupyter!
# 15

# %%
a = 10
b = 3

print("Soma:", a + b)
print("Subtração:", a - b)
print("Multiplicação:", a * b)
print("Divisão:", a / b)
# Out:
# Soma: 13
# Subtração: 7
# Multiplicação: 30
# Divisão: 3.3333333333333335

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/cliente/Área de trabalho/Códigos/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.title("Exemplo de Gráfico")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
