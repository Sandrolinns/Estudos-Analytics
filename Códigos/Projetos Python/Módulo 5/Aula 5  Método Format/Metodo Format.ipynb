# %% [markdown]
# ### Forma que fizemos na última aula (concatenando textos)

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo

print('O faturamento da loja foi ' + str(faturamento) + '.O custo da loja foi ' + str(custo) + '.Assim, o lucro da loja foi de ' + str(lucro))

# %% [markdown]
# ### Método format

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo

print('O faturamento da loja foi {}. O custo fo {}. Assim, o lucro da loja foi {}'.format(faturamento. custo, lucro))
